# %%
import pandas as pd

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# link = 'https://drive.google.com/file/d/1hSfwDlT8_TgExjL5OTaHHKbuF2JmMSV1/view?usp=share_link 
id = '1hSfwDlT8_TgExjL5OTaHHKbuF2JmMSV1'

# %%
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('Flair1.csv',)

# %%
#CSV file 1

data1 = pd.read_csv('Flair1.csv',index_col=[0])
data1
# Out:
#                                                      text  \
# 0       RT @StrikeMapUK: The Cost of Living Crisis is ...
# 1       RT @0Calamity: This is not a #CostOfLivingCris...
# 2       RT @geoffh33: Every non-Tory MP should have st...
# 3       RT @hewitson10: Ian Blackford owned the show a...
# 4       RT @snowy2007: Serious question for Scottish P...
# ...                                                   ...
# 200122  RT @derekjames150: When #BorisJohnson goes to ...
# 200123  RT @rob_kelsall: This is what Solidarity looks...
# 200124  RT @NeilMullens: #BorisJohnson thinks he’s bur...
# 200125  One day closer to the #byelections.\nOne day c...
# 200126  RT @NeilMullens: #BorisJohnson thinks he’s bur...
#
#                                            Cleaned_tweets  probability  \
# 0       cost living crisis political choice yet tory t...     0.924938
# 1       costoflivingcrisis stateimposedpoverty do quit...     0.865847
# ...

# %%
# link = 'https://drive.google.com/file/d/127pezE-Lf-OKAWacvDZlGaD3gO_gVyko/view?usp=share_link

# fluff, 
id = '127pezE-Lf-OKAWacvDZlGaD3gO_gVyko'
# print (id) # Verify that you have everything after '='

# %%
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('Flair2.csv',)

# %%
#CSV file 2

data2 = pd.read_csv('Flair2.csv',index_col=[0])
# Dataset is now stored in a Pandas Dataframe
data2
# Out:
#                                                      text  \
# 200127  RT @NeilMullens: #BorisJohnson thinks he’s bur...
# 200128  RT @rodbishop15: There’s #AngelaRayner out on ...
# 200129  RT @NE4EU: Excellent turnout to #wedemandbette...
# 200130  RT @NeilMullens: #BorisJohnson thinks he’s bur...
# 200131  RT @theokoulouris: We have a brutal, corrupt &...
# ...                                                   ...
# 400180  RT @BootstrapCook: #1 in the ‘15 Minute One Pa...
# 400181  Jack Monroe is revisiting all her recipes and ...
# 400182  RT @clairebubblepop: I’m so angry!!! The Govt ...
# 400183  RT @Steven_Woolfe: Going live on @gbnewsonline...
# 400184  Join me and @GordonBrown and sign this petitio...
#
#                                            Cleaned_tweets  probability  \
# 200127  borisjohnson think bury story try give carrie ...     0.999833
# 200128  angelarayner street support railstrike along w...     0.962503
# ...

# %%
# link = 'https://drive.google.com/file/d/1xRS7vX1da9n8m0vocFEGxFFyPz30Uj0j/view?usp=share_link
id = '1xRS7vX1da9n8m0vocFEGxFFyPz30Uj0j'

# %%
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('Flair3.csv',)

# %%
#CSV file 3

data3 = pd.read_csv('Flair3.csv',index_col=[0])
# Dataset is now stored in a Pandas Dataframe
data3
# Out:
#                                                      text  \
# 400185  RT @SunderlandLolly: "I cannot tell you how da...
# 400186  RT @EllaK189: #BorisJohnson is basically on ga...
# 400187  RT @TheCommonGrd: There are popular solutions ...
# 400188  RT @SineadPaghan: Dear Jesus this is disastrou...
# 400189  RT @toryboypierce: Pledge from #liztruss @dail...
# ...                                                   ...
# 541723  RT @SB_Sarah10: Do you honestly think #LizTrus...
# 541724  RT @michaelbartrum: Every hour, 10 people die ...
# 541725  Jesus! £170 billion excess profits over 2 yrs!...
# 541726  RT @maxwellwoodger: Attended the Final @Conser...
# 541727  #BorisJohnson plans to visit sites of his grea...
#
#                                            Cleaned_tweets  probability  \
# 400185  can not tell dangerous come go idea can not an...     0.978217
# 400186  borisjohnson basically garden leave busy campa...     0.998941
# ...

# %%
# merging csv files
data = pd.concat([data1,data2,data3])
data
# Out:
#                                                      text  \
# 0       RT @StrikeMapUK: The Cost of Living Crisis is ...
# 1       RT @0Calamity: This is not a #CostOfLivingCris...
# 2       RT @geoffh33: Every non-Tory MP should have st...
# 3       RT @hewitson10: Ian Blackford owned the show a...
# 4       RT @snowy2007: Serious question for Scottish P...
# ...                                                   ...
# 541723  RT @SB_Sarah10: Do you honestly think #LizTrus...
# 541724  RT @michaelbartrum: Every hour, 10 people die ...
# 541725  Jesus! £170 billion excess profits over 2 yrs!...
# 541726  RT @maxwellwoodger: Attended the Final @Conser...
# 541727  #BorisJohnson plans to visit sites of his grea...
#
#                                            Cleaned_tweets  probability  \
# 0       cost living crisis political choice yet tory t...     0.924938
# 1       costoflivingcrisis stateimposedpoverty do quit...     0.865847
# ...

# %%
# data.info()

# %%
data.to_csv('FlairAnalysis_new.csv')

# %%
fa_counts= data['sentiment'].value_counts()
fa_counts
# Out:
# NEGATIVE    374184
# POSITIVE    167328
# Name: sentiment, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
plt.pie(fa_counts.values, labels = fa_counts.index, explode = (0.1, 0), autopct='%1.1f%%', shadow=False)
plt.savefig('FlairAnalysis_new.jpg')
plt.legend()
